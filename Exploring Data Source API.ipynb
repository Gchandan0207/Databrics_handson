# %%
# %sql
SELECT 1 as number

# %%
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
print(type(df))
df.printSchema()
df.display()

# %%
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.dat",
    header=True,
    inferSchema=True,
    sep="|"
)
print(type(df))
df.printSchema()
df.display()

# %%
df = spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.json",
)
print(type(df))
df.printSchema()
df.display()

# %%
# json with multiple lines then it should be array of json
df = spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_002.json",
    multiLine=True
)
print(type(df))
df.printSchema()
df.display()

# %%
# json with multiple lines then it should be array of json if not then it will take records after 1st line will be null
df = spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_003.json",
    multiLine=True
)
print(type(df))
df.printSchema()
df.display()

# %%
# json with multiple lines then it should be array of json
df = spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_004.json",
    multiLine=True
)
print(type(df))
df.printSchema()
df.display()

# %%
spark.read.parquet("/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users.parquet").display()

# %% [markdown]
# #Dealing Bad Record

# %%
spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json").display()

# %%
# default corrupt revcord is permmisive
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",
    mode="PERMISSIVE",
).display()

# %%
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",
    mode="DROPMALFORMED",
).display()

# %%
# wont load in FAILFAST
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",
    mode="FAILFAST",
).display()

# %% [markdown]
# #Dataframe Writer API

# %%
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
).write.format("JSON").save(
    "/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_json/"
)

# %% [markdown]
# #Output Modes
# # default o/p mode "Error if exists"

# %%
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
).write.format("JSON").save(
    "/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_json/",
    mode="error"
)

# %%
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
).write.format("JSON").save(
    "/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_json/",
    mode="OVERWRITE"
)

# %%
spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
).write.format("JSON").save(
    "/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_json/",
    mode="IGNORE"
)
